# %%
from __future__ import print_function
# %load_ext autoreload
# %autoreload 2
import os, pickle
from collections import defaultdict, OrderedDict

import numpy as np
import keras.backend as K

import kde
import simplebinmi
import pdb

import utils
trn, tst = utils.get_mnist()

# Which measure to plot
infoplane_measure = 'upper'
#infoplane_measure = 'bin'

DO_SAVE        = True    # Whether to save plots or just show them
DO_LOWER       = True    # (infoplane_measure == 'lower')   # Whether to compute lower bounds also
DO_BINNED      = True    #(infoplane_measure == 'bin')     # Whether to compute MI estimates based on binning

MAX_EPOCHS = 10000      # Max number of epoch for which to compute mutual information measure
# MAX_EPOCHS = 1000
COLORBAR_MAX_EPOCHS = 10000

# Directories from which to load saved layer activity
ARCH = '1024-20-20-20'
#ARCH = '20-20-20-20-20-20'
#ARCH = '32-28-24-20-16-12'
#ARCH = '32-28-24-20-16-12-8-8'
DIR_TEMPLATE = '%%s_%s'%ARCH

# Functions to return upper and lower bounds on entropy of layer activity 
#K what is entropy of a layer, computes
noise_variance = 1e-1                    # Added Gaussian noise variance
Klayer_activity = K.placeholder(ndim=2)  # Keras placeholder 
#pdb.set_trace()
entropy_func_upper = K.function([Klayer_activity,], [kde.entropy_estimator_kl(Klayer_activity, noise_variance),])
entropy_func_lower = K.function([Klayer_activity,], [kde.entropy_estimator_bd(Klayer_activity, noise_variance),])


# nats to bits conversion factor
nats2bits = 1.0/np.log(2) 


# Save indexes of tests data for each of the output classes
saved_labelixs = {}
for i in range(10):
    saved_labelixs[i] = tst.y == i

labelprobs = np.mean(tst.Y, axis=0)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
PLOT_LAYERS    = None     # Which layers to plot.  If None, all saved layers are plotted 

# Data structure used to store results
measures = OrderedDict()
measures['relu'] = {}
measures['tanh'] = {}

# %% [markdown]
# Compute MI measures
# -----

# %%
for activation in measures.keys():
    cur_dir = 'rawdata/' + DIR_TEMPLATE % activation
    if not os.path.exists(cur_dir):
        print("Directory %s not found" % cur_dir)
        continue
        
    # Load files saved during each epoch, and compute MI measures of the activity in that epoch
    print('*** Doing %s ***' % cur_dir)
    for epochfile in sorted(os.listdir(cur_dir)):
        if not epochfile.startswith('epoch'):
            continue
            
        fname = cur_dir + "/" + epochfile
        with open(fname, 'rb') as f:
            d = pickle.load(f)

        epoch = d['epoch']
        if epoch in measures[activation]: # Skip this epoch if its already been processed
            continue                      # this is a trick to allow us to rerun this cell multiple times)
            
        if epoch > MAX_EPOCHS:
            continue

        print("Doing", fname)
        
        num_layers = len(d['data']['activity_tst'])

        if PLOT_LAYERS is None:
            PLOT_LAYERS = []
            for lndx in range(num_layers):
                #if d['data']['activity_tst'][lndx].shape[1] < 200 and lndx != num_layers - 1:
                PLOT_LAYERS.append(lndx)
                
        cepochdata = defaultdict(list)
    
        # here we compute entropies or mutual informations for each layer
        for lndx in range(num_layers):
            activity = d['data']['activity_tst'][lndx] #K activity for each layer, they're of size 1024x10000, 20x10000, etc.
            #pdb.set_trace()

            # Compute marginal entropies
            h_upper = entropy_func_upper([activity,])[0]
            if DO_LOWER:
                h_lower = entropy_func_lower([activity,])[0]
                
            # Layer activity given input. This is simply the entropy of the Gaussian noise
            hM_given_X = kde.kde_condentropy(activity, noise_variance)

            # Compute conditional entropies of layer activity given output
            hM_given_Y_upper=0.
            for i in range(10):
                hcond_upper = entropy_func_upper([activity[saved_labelixs[i],:],])[0]
                hM_given_Y_upper += labelprobs[i] * hcond_upper
                
            if DO_LOWER:
                hM_given_Y_lower=0.
                for i in range(10):
                    hcond_lower = entropy_func_lower([activity[saved_labelixs[i],:],])[0]
                    hM_given_Y_lower += labelprobs[i] * hcond_lower
                    
                    
            # # It's also possible to treat the last layer probabilistically. Here is the 
            # # code to do so. Should only be applied when lndx == num_layers - 1

            # ps = activity.mean(axis=0)
            # h_lower = h_upper = sum([-p*np.log(p) for p in ps if p != 0])

            # x = -activity * np.log(activity)
            # x[activity == 0] = 0.
            # hM_given_X = np.mean(x.sum(axis=1))

            # hM_given_Y=0.
            # for i in range(10):
            #     ixs = tst.y[::subsample] == i
            #     ps = activity[ixs,:].mean(axis=0)
            #     hcond = sum([-p*np.log(p) for p in ps if p != 0])
            #     prob = np.mean(ixs)
            #     hM_given_Y += l * hcond
            # hM_given_Y_lower = hM_given_Y_upper = hM_given_Y
            # del hM_given_Y
                
            #K why do we subtract
            cepochdata['MI_XM_upper'].append( nats2bits * (h_upper - hM_given_X) )
            cepochdata['MI_YM_upper'].append( nats2bits * (h_upper - hM_given_Y_upper) )
            cepochdata['H_M_upper'  ].append( nats2bits * h_upper )

            pstr = 'upper: MI(X;M)=%0.3f, MI(Y;M)=%0.3f' % (cepochdata['MI_XM_upper'][-1], cepochdata['MI_YM_upper'][-1])
            if DO_LOWER:  # Compute lower bounds
                cepochdata['MI_XM_lower'].append( nats2bits * (h_lower - hM_given_X) )
                cepochdata['MI_YM_lower'].append( nats2bits * (h_lower - hM_given_Y_lower) )
                cepochdata['H_M_lower'  ].append( nats2bits * h_lower )
                pstr += ' | lower: MI(X;M)=%0.3f, MI(Y;M)=%0.3f' % (cepochdata['MI_XM_lower'][-1], cepochdata['MI_YM_lower'][-1])

            if DO_BINNED: # Compute binner estimates
                binxm, binym = simplebinmi.bin_calc_information2(saved_labelixs, activity, 0.5)
                cepochdata['MI_XM_bin'].append( nats2bits * binxm )
                cepochdata['MI_YM_bin'].append( nats2bits * binym )
                pstr += ' | bin: MI(X;M)=%0.3f, MI(Y;M)=%0.3f' % (cepochdata['MI_XM_bin'][-1], cepochdata['MI_YM_bin'][-1])
            
            print('- Layer %d %s' % (lndx, pstr) )

        measures[activation][epoch] = cepochdata
# Out:
# Directory rawdata/relu_1024-20-20-20 not found
# *** Doing rawdata/tanh_1024-20-20-20 ***
# Doing rawdata/tanh_1024-20-20-20/epoch00000000
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=11.405, MI(Y;M)=3.018 | lower: MI(X;M)=5.372, MI(Y;M)=1.704 | bin: MI(X;M)=13.198, MI(Y;M)=3.316
# - Layer 2 upper: MI(X;M)=10.135, MI(Y;M)=2.694 | lower: MI(X;M)=4.838, MI(Y;M)=1.648 | bin: MI(X;M)=13.058, MI(Y;M)=3.302
# - Layer 3 upper: MI(X;M)=8.722, MI(Y;M)=2.366 | lower: MI(X;M)=4.115, MI(Y;M)=1.480 | bin: MI(X;M)=12.774, MI(Y;M)=3.229
# - Layer 4 upper: MI(X;M)=0.297, MI(Y;M)=0.182 | lower: MI(X;M)=0.078, MI(Y;M)=0.048 | bin: MI(X;M)=-0.000, MI(Y;M)=-0.000
# Doing rawdata/tanh_1024-20-20-20/epoch00000001
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=11.673, MI(Y;M)=3.161 | lower: MI(X;M)=6.156, MI(Y;M)=2.145 | bin: MI(X;M)=13.220, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.523, MI(Y;M)=2.953 | lower: MI(X;M)=5.571, MI(Y;M)=2.089 | bin: MI(X;M)=13.080, MI(Y;M)=3.311
# - Layer 3 upper: MI(X;M)=9.198, MI(Y;M)=2.707 | lower: MI(X;M)=4.797, MI(Y;M)=1.925 | bin: MI(X;M)=12.827, MI(Y;M)=3.282
# - Layer 4 upper: MI(X;M)=0.547, MI(Y;M)=0.369 | lower: MI(X;M)=0.147, MI(Y;M)=0.101 | bin: MI(X;M)=0.003, MI(Y;M)=0.001
# Doing rawdata/tanh_1024-20-20-20/epoch00000002
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=11.940, MI(Y;M)=3.237 | lower: MI(X;M)=6.828, MI(Y;M)=2.395 | bin: MI(X;M)=13.197, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.709, MI(Y;M)=3.063 | lower: MI(X;M)=5.936, MI(Y;M)=2.311 | bin: MI(X;M)=13.085, MI(Y;M)=3.316
# - Layer 3 upper: MI(X;M)=9.646, MI(Y;M)=2.887 | lower: MI(X;M)=5.525, MI(Y;M)=2.273 | bin: MI(X;M)=12.862, MI(Y;M)=3.293
# - Layer 4 upper: MI(X;M)=0.872, MI(Y;M)=0.585 | lower: MI(X;M)=0.236, MI(Y;M)=0.160 | bin: MI(X;M)=0.136, MI(Y;M)=0.059
# Doing rawdata/tanh_1024-20-20-20/epoch00000003
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=11.954, MI(Y;M)=3.254 | lower: MI(X;M)=7.064, MI(Y;M)=2.511 | bin: MI(X;M)=13.181, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.746, MI(Y;M)=3.110 | lower: MI(X;M)=6.152, MI(Y;M)=2.429 | bin: MI(X;M)=13.070, MI(Y;M)=3.314
# - Layer 3 upper: MI(X;M)=9.756, MI(Y;M)=2.967 | lower: MI(X;M)=5.756, MI(Y;M)=2.398 | bin: MI(X;M)=12.795, MI(Y;M)=3.299
# - Layer 4 upper: MI(X;M)=1.153, MI(Y;M)=0.802 | lower: MI(X;M)=0.319, MI(Y;M)=0.225 | bin: MI(X;M)=0.396, MI(Y;M)=0.208
# Doing rawdata/tanh_1024-20-20-20/epoch00000004
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=11.961, MI(Y;M)=3.265 | lower: MI(X;M)=7.236, MI(Y;M)=2.596 | bin: MI(X;M)=13.170, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.765, MI(Y;M)=3.142 | lower: MI(X;M)=6.305, MI(Y;M)=2.516 | bin: MI(X;M)=13.031, MI(Y;M)=3.315
# - Layer 3 upper: MI(X;M)=9.829, MI(Y;M)=3.022 | lower: MI(X;M)=5.923, MI(Y;M)=2.490 | bin: MI(X;M)=12.743, MI(Y;M)=3.303
# - Layer 4 upper: MI(X;M)=1.435, MI(Y;M)=1.025 | lower: MI(X;M)=0.407, MI(Y;M)=0.296 | bin: MI(X;M)=0.709, MI(Y;M)=0.391
# Doing rawdata/tanh_1024-20-20-20/epoch00000005
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=11.963, MI(Y;M)=3.272 | lower: MI(X;M)=7.364, MI(Y;M)=2.660 | bin: MI(X;M)=13.149, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.773, MI(Y;M)=3.164 | lower: MI(X;M)=6.418, MI(Y;M)=2.583 | bin: MI(X;M)=13.007, MI(Y;M)=3.315
# - Layer 3 upper: MI(X;M)=9.879, MI(Y;M)=3.062 | lower: MI(X;M)=6.048, MI(Y;M)=2.561 | bin: MI(X;M)=12.697, MI(Y;M)=3.307
# - Layer 4 upper: MI(X;M)=1.703, MI(Y;M)=1.241 | lower: MI(X;M)=0.496, MI(Y;M)=0.369 | bin: MI(X;M)=1.478, MI(Y;M)=0.833
# Doing rawdata/tanh_1024-20-20-20/epoch00000006
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=11.964, MI(Y;M)=3.278 | lower: MI(X;M)=7.465, MI(Y;M)=2.711 | bin: MI(X;M)=13.141, MI(Y;M)=3.318
# - Layer 2 upper: MI(X;M)=10.776, MI(Y;M)=3.181 | lower: MI(X;M)=6.505, MI(Y;M)=2.636 | bin: MI(X;M)=12.998, MI(Y;M)=3.316
# - Layer 3 upper: MI(X;M)=9.912, MI(Y;M)=3.092 | lower: MI(X;M)=6.146, MI(Y;M)=2.617 | bin: MI(X;M)=12.654, MI(Y;M)=3.304
# - Layer 4 upper: MI(X;M)=1.952, MI(Y;M)=1.442 | lower: MI(X;M)=0.587, MI(Y;M)=0.444 | bin: MI(X;M)=2.013, MI(Y;M)=1.234
# Doing rawdata/tanh_1024-20-20-20/epoch00000007
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=11.963, MI(Y;M)=3.282 | lower: MI(X;M)=7.546, MI(Y;M)=2.753 | bin: MI(X;M)=13.141, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.775, MI(Y;M)=3.194 | lower: MI(X;M)=6.573, MI(Y;M)=2.680 | bin: MI(X;M)=12.989, MI(Y;M)=3.316
# - Layer 3 upper: MI(X;M)=9.936, MI(Y;M)=3.116 | lower: MI(X;M)=6.224, MI(Y;M)=2.664 | bin: MI(X;M)=12.621, MI(Y;M)=3.307
# - Layer 4 upper: MI(X;M)=2.174, MI(Y;M)=1.623 | lower: MI(X;M)=0.675, MI(Y;M)=0.519 | bin: MI(X;M)=2.340, MI(Y;M)=1.521
# Doing rawdata/tanh_1024-20-20-20/epoch00000008
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=11.962, MI(Y;M)=3.286 | lower: MI(X;M)=7.610, MI(Y;M)=2.788 | bin: MI(X;M)=13.138, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.771, MI(Y;M)=3.204 | lower: MI(X;M)=6.628, MI(Y;M)=2.717 | bin: MI(X;M)=12.956, MI(Y;M)=3.316
# - Layer 3 upper: MI(X;M)=9.950, MI(Y;M)=3.134 | lower: MI(X;M)=6.286, MI(Y;M)=2.702 | bin: MI(X;M)=12.583, MI(Y;M)=3.305
# - Layer 4 upper: MI(X;M)=2.371, MI(Y;M)=1.783 | lower: MI(X;M)=0.761, MI(Y;M)=0.593 | bin: MI(X;M)=2.562, MI(Y;M)=1.722
# Doing rawdata/tanh_1024-20-20-20/epoch00000009
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=11.960, MI(Y;M)=3.289 | lower: MI(X;M)=7.663, MI(Y;M)=2.817 | bin: MI(X;M)=13.123, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.768, MI(Y;M)=3.213 | lower: MI(X;M)=6.672, MI(Y;M)=2.748 | bin: MI(X;M)=12.934, MI(Y;M)=3.316
# - Layer 3 upper: MI(X;M)=9.961, MI(Y;M)=3.149 | lower: MI(X;M)=6.338, MI(Y;M)=2.736 | bin: MI(X;M)=12.527, MI(Y;M)=3.306
# - Layer 4 upper: MI(X;M)=2.540, MI(Y;M)=1.920 | lower: MI(X;M)=0.842, MI(Y;M)=0.662 | bin: MI(X;M)=2.735, MI(Y;M)=1.857
# Doing rawdata/tanh_1024-20-20-20/epoch00000010
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=11.959, MI(Y;M)=3.291 | lower: MI(X;M)=7.708, MI(Y;M)=2.842 | bin: MI(X;M)=13.107, MI(Y;M)=3.318
# - Layer 2 upper: MI(X;M)=10.763, MI(Y;M)=3.220 | lower: MI(X;M)=6.710, MI(Y;M)=2.774 | bin: MI(X;M)=12.912, MI(Y;M)=3.316
# - Layer 3 upper: MI(X;M)=9.968, MI(Y;M)=3.161 | lower: MI(X;M)=6.383, MI(Y;M)=2.764 | bin: MI(X;M)=12.488, MI(Y;M)=3.306
# - Layer 4 upper: MI(X;M)=2.685, MI(Y;M)=2.037 | lower: MI(X;M)=0.919, MI(Y;M)=0.728 | bin: MI(X;M)=2.886, MI(Y;M)=1.974
# Doing rawdata/tanh_1024-20-20-20/epoch00000011
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=11.957, MI(Y;M)=3.293 | lower: MI(X;M)=7.747, MI(Y;M)=2.863 | bin: MI(X;M)=13.088, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.761, MI(Y;M)=3.226 | lower: MI(X;M)=6.744, MI(Y;M)=2.797 | bin: MI(X;M)=12.889, MI(Y;M)=3.316
# - Layer 3 upper: MI(X;M)=9.975, MI(Y;M)=3.171 | lower: MI(X;M)=6.422, MI(Y;M)=2.788 | bin: MI(X;M)=12.446, MI(Y;M)=3.306
# - Layer 4 upper: MI(X;M)=2.812, MI(Y;M)=2.139 | lower: MI(X;M)=0.992, MI(Y;M)=0.792 | bin: MI(X;M)=3.027, MI(Y;M)=2.088
# Doing rawdata/tanh_1024-20-20-20/epoch00000012
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=11.954, MI(Y;M)=3.295 | lower: MI(X;M)=7.776, MI(Y;M)=2.882 | bin: MI(X;M)=13.073, MI(Y;M)=3.318
# - Layer 2 upper: MI(X;M)=10.755, MI(Y;M)=3.231 | lower: MI(X;M)=6.767, MI(Y;M)=2.818 | bin: MI(X;M)=12.872, MI(Y;M)=3.315
# - Layer 3 upper: MI(X;M)=9.973, MI(Y;M)=3.179 | lower: MI(X;M)=6.449, MI(Y;M)=2.809 | bin: MI(X;M)=12.408, MI(Y;M)=3.306
# - Layer 4 upper: MI(X;M)=2.919, MI(Y;M)=2.227 | lower: MI(X;M)=1.061, MI(Y;M)=0.852 | bin: MI(X;M)=3.137, MI(Y;M)=2.177
# Doing rawdata/tanh_1024-20-20-20/epoch00000013
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=11.952, MI(Y;M)=3.296 | lower: MI(X;M)=7.805, MI(Y;M)=2.897 | bin: MI(X;M)=13.062, MI(Y;M)=3.318
# - Layer 2 upper: MI(X;M)=10.746, MI(Y;M)=3.235 | lower: MI(X;M)=6.788, MI(Y;M)=2.834 | bin: MI(X;M)=12.853, MI(Y;M)=3.317
# - Layer 3 upper: MI(X;M)=9.968, MI(Y;M)=3.186 | lower: MI(X;M)=6.473, MI(Y;M)=2.827 | bin: MI(X;M)=12.369, MI(Y;M)=3.306
# - Layer 4 upper: MI(X;M)=3.012, MI(Y;M)=2.302 | lower: MI(X;M)=1.125, MI(Y;M)=0.909 | bin: MI(X;M)=3.215, MI(Y;M)=2.255
# Doing rawdata/tanh_1024-20-20-20/epoch00000014
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=11.949, MI(Y;M)=3.298 | lower: MI(X;M)=7.826, MI(Y;M)=2.912 | bin: MI(X;M)=13.052, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.739, MI(Y;M)=3.239 | lower: MI(X;M)=6.805, MI(Y;M)=2.850 | bin: MI(X;M)=12.834, MI(Y;M)=3.316
# - Layer 3 upper: MI(X;M)=9.964, MI(Y;M)=3.193 | lower: MI(X;M)=6.492, MI(Y;M)=2.844 | bin: MI(X;M)=12.335, MI(Y;M)=3.306
# - Layer 4 upper: MI(X;M)=3.091, MI(Y;M)=2.366 | lower: MI(X;M)=1.185, MI(Y;M)=0.962 | bin: MI(X;M)=3.274, MI(Y;M)=2.310
# Doing rawdata/tanh_1024-20-20-20/epoch00000015
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=11.946, MI(Y;M)=3.299 | lower: MI(X;M)=7.846, MI(Y;M)=2.924 | bin: MI(X;M)=13.037, MI(Y;M)=3.318
# - Layer 2 upper: MI(X;M)=10.729, MI(Y;M)=3.242 | lower: MI(X;M)=6.818, MI(Y;M)=2.863 | bin: MI(X;M)=12.826, MI(Y;M)=3.317
# - Layer 3 upper: MI(X;M)=9.957, MI(Y;M)=3.198 | lower: MI(X;M)=6.508, MI(Y;M)=2.858 | bin: MI(X;M)=12.303, MI(Y;M)=3.307
# - Layer 4 upper: MI(X;M)=3.160, MI(Y;M)=2.422 | lower: MI(X;M)=1.241, MI(Y;M)=1.012 | bin: MI(X;M)=3.321, MI(Y;M)=2.363
# Doing rawdata/tanh_1024-20-20-20/epoch00000016
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=11.943, MI(Y;M)=3.300 | lower: MI(X;M)=7.864, MI(Y;M)=2.935 | bin: MI(X;M)=13.029, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.722, MI(Y;M)=3.245 | lower: MI(X;M)=6.831, MI(Y;M)=2.876 | bin: MI(X;M)=12.804, MI(Y;M)=3.317
# - Layer 3 upper: MI(X;M)=9.951, MI(Y;M)=3.203 | lower: MI(X;M)=6.522, MI(Y;M)=2.871 | bin: MI(X;M)=12.278, MI(Y;M)=3.307
# - Layer 4 upper: MI(X;M)=3.218, MI(Y;M)=2.469 | lower: MI(X;M)=1.294, MI(Y;M)=1.059 | bin: MI(X;M)=3.355, MI(Y;M)=2.410
# Doing rawdata/tanh_1024-20-20-20/epoch00000017
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=11.941, MI(Y;M)=3.301 | lower: MI(X;M)=7.881, MI(Y;M)=2.946 | bin: MI(X;M)=13.016, MI(Y;M)=3.318
# - Layer 2 upper: MI(X;M)=10.716, MI(Y;M)=3.248 | lower: MI(X;M)=6.843, MI(Y;M)=2.887 | bin: MI(X;M)=12.779, MI(Y;M)=3.317
# - Layer 3 upper: MI(X;M)=9.943, MI(Y;M)=3.207 | lower: MI(X;M)=6.533, MI(Y;M)=2.883 | bin: MI(X;M)=12.246, MI(Y;M)=3.310
# - Layer 4 upper: MI(X;M)=3.268, MI(Y;M)=2.511 | lower: MI(X;M)=1.343, MI(Y;M)=1.104 | bin: MI(X;M)=3.376, MI(Y;M)=2.439
# Doing rawdata/tanh_1024-20-20-20/epoch00000018
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=11.939, MI(Y;M)=3.302 | lower: MI(X;M)=7.896, MI(Y;M)=2.955 | bin: MI(X;M)=13.005, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.709, MI(Y;M)=3.251 | lower: MI(X;M)=6.852, MI(Y;M)=2.897 | bin: MI(X;M)=12.764, MI(Y;M)=3.317
# - Layer 3 upper: MI(X;M)=9.937, MI(Y;M)=3.211 | lower: MI(X;M)=6.544, MI(Y;M)=2.894 | bin: MI(X;M)=12.229, MI(Y;M)=3.311
# - Layer 4 upper: MI(X;M)=3.311, MI(Y;M)=2.546 | lower: MI(X;M)=1.389, MI(Y;M)=1.145 | bin: MI(X;M)=3.397, MI(Y;M)=2.472
# Doing rawdata/tanh_1024-20-20-20/epoch00000019
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=11.937, MI(Y;M)=3.302 | lower: MI(X;M)=7.910, MI(Y;M)=2.964 | bin: MI(X;M)=13.005, MI(Y;M)=3.318
# - Layer 2 upper: MI(X;M)=10.704, MI(Y;M)=3.253 | lower: MI(X;M)=6.862, MI(Y;M)=2.907 | bin: MI(X;M)=12.754, MI(Y;M)=3.317
# - Layer 3 upper: MI(X;M)=9.931, MI(Y;M)=3.215 | lower: MI(X;M)=6.553, MI(Y;M)=2.904 | bin: MI(X;M)=12.201, MI(Y;M)=3.310
# - Layer 4 upper: MI(X;M)=3.348, MI(Y;M)=2.577 | lower: MI(X;M)=1.431, MI(Y;M)=1.184 | bin: MI(X;M)=3.410, MI(Y;M)=2.495
# Doing rawdata/tanh_1024-20-20-20/epoch00000020
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=11.935, MI(Y;M)=3.303 | lower: MI(X;M)=7.920, MI(Y;M)=2.971 | bin: MI(X;M)=12.999, MI(Y;M)=3.318
# - Layer 2 upper: MI(X;M)=10.693, MI(Y;M)=3.255 | lower: MI(X;M)=6.864, MI(Y;M)=2.914 | bin: MI(X;M)=12.735, MI(Y;M)=3.317
# - Layer 3 upper: MI(X;M)=9.916, MI(Y;M)=3.218 | lower: MI(X;M)=6.554, MI(Y;M)=2.912 | bin: MI(X;M)=12.167, MI(Y;M)=3.311
# - Layer 4 upper: MI(X;M)=3.379, MI(Y;M)=2.604 | lower: MI(X;M)=1.471, MI(Y;M)=1.220 | bin: MI(X;M)=3.423, MI(Y;M)=2.516
# Doing rawdata/tanh_1024-20-20-20/epoch00000025
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=11.931, MI(Y;M)=3.305 | lower: MI(X;M)=7.979, MI(Y;M)=3.003 | bin: MI(X;M)=12.959, MI(Y;M)=3.317
# - Layer 2 upper: MI(X;M)=10.671, MI(Y;M)=3.264 | lower: MI(X;M)=6.897, MI(Y;M)=2.949 | bin: MI(X;M)=12.688, MI(Y;M)=3.317
# - Layer 3 upper: MI(X;M)=9.884, MI(Y;M)=3.232 | lower: MI(X;M)=6.581, MI(Y;M)=2.948 | bin: MI(X;M)=12.087, MI(Y;M)=3.311
# - Layer 4 upper: MI(X;M)=3.483, MI(Y;M)=2.696 | lower: MI(X;M)=1.635, MI(Y;M)=1.372 | bin: MI(X;M)=3.446, MI(Y;M)=2.591
# Doing rawdata/tanh_1024-20-20-20/epoch00000030
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=11.937, MI(Y;M)=3.307 | lower: MI(X;M)=8.025, MI(Y;M)=3.026 | bin: MI(X;M)=12.946, MI(Y;M)=3.318
# - Layer 2 upper: MI(X;M)=10.657, MI(Y;M)=3.270 | lower: MI(X;M)=6.914, MI(Y;M)=2.973 | bin: MI(X;M)=12.652, MI(Y;M)=3.317
# - Layer 3 upper: MI(X;M)=9.850, MI(Y;M)=3.241 | lower: MI(X;M)=6.589, MI(Y;M)=2.973 | bin: MI(X;M)=12.015, MI(Y;M)=3.312
# - Layer 4 upper: MI(X;M)=3.534, MI(Y;M)=2.749 | lower: MI(X;M)=1.752, MI(Y;M)=1.484 | bin: MI(X;M)=3.451, MI(Y;M)=2.629
# Doing rawdata/tanh_1024-20-20-20/epoch00000035
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=11.943, MI(Y;M)=3.309 | lower: MI(X;M)=8.070, MI(Y;M)=3.044 | bin: MI(X;M)=12.913, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.648, MI(Y;M)=3.275 | lower: MI(X;M)=6.933, MI(Y;M)=2.993 | bin: MI(X;M)=12.631, MI(Y;M)=3.317
# - Layer 3 upper: MI(X;M)=9.829, MI(Y;M)=3.249 | lower: MI(X;M)=6.600, MI(Y;M)=2.994 | bin: MI(X;M)=11.956, MI(Y;M)=3.312
# - Layer 4 upper: MI(X;M)=3.562, MI(Y;M)=2.783 | lower: MI(X;M)=1.840, MI(Y;M)=1.570 | bin: MI(X;M)=3.451, MI(Y;M)=2.661
# Doing rawdata/tanh_1024-20-20-20/epoch00000040
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=11.951, MI(Y;M)=3.310 | lower: MI(X;M)=8.108, MI(Y;M)=3.058 | bin: MI(X;M)=12.904, MI(Y;M)=3.318
# - Layer 2 upper: MI(X;M)=10.643, MI(Y;M)=3.278 | lower: MI(X;M)=6.948, MI(Y;M)=3.008 | bin: MI(X;M)=12.619, MI(Y;M)=3.316
# - Layer 3 upper: MI(X;M)=9.809, MI(Y;M)=3.254 | lower: MI(X;M)=6.605, MI(Y;M)=3.011 | bin: MI(X;M)=11.923, MI(Y;M)=3.312
# - Layer 4 upper: MI(X;M)=3.577, MI(Y;M)=2.808 | lower: MI(X;M)=1.907, MI(Y;M)=1.637 | bin: MI(X;M)=3.448, MI(Y;M)=2.685
# Doing rawdata/tanh_1024-20-20-20/epoch00000045
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=11.961, MI(Y;M)=3.311 | lower: MI(X;M)=8.144, MI(Y;M)=3.071 | bin: MI(X;M)=12.904, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.643, MI(Y;M)=3.282 | lower: MI(X;M)=6.961, MI(Y;M)=3.022 | bin: MI(X;M)=12.599, MI(Y;M)=3.317
# - Layer 3 upper: MI(X;M)=9.791, MI(Y;M)=3.258 | lower: MI(X;M)=6.607, MI(Y;M)=3.025 | bin: MI(X;M)=11.875, MI(Y;M)=3.311
# - Layer 4 upper: MI(X;M)=3.584, MI(Y;M)=2.828 | lower: MI(X;M)=1.960, MI(Y;M)=1.692 | bin: MI(X;M)=3.446, MI(Y;M)=2.699
# Doing rawdata/tanh_1024-20-20-20/epoch00000050
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=11.971, MI(Y;M)=3.311 | lower: MI(X;M)=8.176, MI(Y;M)=3.081 | bin: MI(X;M)=12.899, MI(Y;M)=3.318
# - Layer 2 upper: MI(X;M)=10.646, MI(Y;M)=3.284 | lower: MI(X;M)=6.973, MI(Y;M)=3.033 | bin: MI(X;M)=12.595, MI(Y;M)=3.316
# - Layer 3 upper: MI(X;M)=9.780, MI(Y;M)=3.262 | lower: MI(X;M)=6.609, MI(Y;M)=3.037 | bin: MI(X;M)=11.871, MI(Y;M)=3.312
# - Layer 4 upper: MI(X;M)=3.588, MI(Y;M)=2.843 | lower: MI(X;M)=2.001, MI(Y;M)=1.735 | bin: MI(X;M)=3.443, MI(Y;M)=2.719
# Doing rawdata/tanh_1024-20-20-20/epoch00000055
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=11.983, MI(Y;M)=3.312 | lower: MI(X;M)=8.209, MI(Y;M)=3.091 | bin: MI(X;M)=12.896, MI(Y;M)=3.318
# - Layer 2 upper: MI(X;M)=10.651, MI(Y;M)=3.287 | lower: MI(X;M)=6.985, MI(Y;M)=3.042 | bin: MI(X;M)=12.590, MI(Y;M)=3.316
# - Layer 3 upper: MI(X;M)=9.770, MI(Y;M)=3.266 | lower: MI(X;M)=6.610, MI(Y;M)=3.048 | bin: MI(X;M)=11.832, MI(Y;M)=3.312
# - Layer 4 upper: MI(X;M)=3.590, MI(Y;M)=2.858 | lower: MI(X;M)=2.036, MI(Y;M)=1.773 | bin: MI(X;M)=3.442, MI(Y;M)=2.737
# Doing rawdata/tanh_1024-20-20-20/epoch00000060
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=11.995, MI(Y;M)=3.313 | lower: MI(X;M)=8.243, MI(Y;M)=3.099 | bin: MI(X;M)=12.884, MI(Y;M)=3.318
# - Layer 2 upper: MI(X;M)=10.660, MI(Y;M)=3.289 | lower: MI(X;M)=7.001, MI(Y;M)=3.051 | bin: MI(X;M)=12.587, MI(Y;M)=3.317
# - Layer 3 upper: MI(X;M)=9.769, MI(Y;M)=3.269 | lower: MI(X;M)=6.618, MI(Y;M)=3.058 | bin: MI(X;M)=11.815, MI(Y;M)=3.311
# - Layer 4 upper: MI(X;M)=3.590, MI(Y;M)=2.870 | lower: MI(X;M)=2.065, MI(Y;M)=1.805 | bin: MI(X;M)=3.439, MI(Y;M)=2.748
# Doing rawdata/tanh_1024-20-20-20/epoch00000065
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.007, MI(Y;M)=3.313 | lower: MI(X;M)=8.273, MI(Y;M)=3.107 | bin: MI(X;M)=12.886, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.669, MI(Y;M)=3.291 | lower: MI(X;M)=7.014, MI(Y;M)=3.059 | bin: MI(X;M)=12.587, MI(Y;M)=3.316
# - Layer 3 upper: MI(X;M)=9.765, MI(Y;M)=3.271 | lower: MI(X;M)=6.620, MI(Y;M)=3.067 | bin: MI(X;M)=11.808, MI(Y;M)=3.311
# - Layer 4 upper: MI(X;M)=3.589, MI(Y;M)=2.881 | lower: MI(X;M)=2.090, MI(Y;M)=1.833 | bin: MI(X;M)=3.436, MI(Y;M)=2.764
# Doing rawdata/tanh_1024-20-20-20/epoch00000070
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.020, MI(Y;M)=3.314 | lower: MI(X;M)=8.304, MI(Y;M)=3.113 | bin: MI(X;M)=12.878, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.678, MI(Y;M)=3.292 | lower: MI(X;M)=7.028, MI(Y;M)=3.066 | bin: MI(X;M)=12.599, MI(Y;M)=3.317
# - Layer 3 upper: MI(X;M)=9.767, MI(Y;M)=3.274 | lower: MI(X;M)=6.627, MI(Y;M)=3.075 | bin: MI(X;M)=11.791, MI(Y;M)=3.311
# - Layer 4 upper: MI(X;M)=3.588, MI(Y;M)=2.891 | lower: MI(X;M)=2.111, MI(Y;M)=1.858 | bin: MI(X;M)=3.434, MI(Y;M)=2.779
# Doing rawdata/tanh_1024-20-20-20/epoch00000075
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.036, MI(Y;M)=3.314 | lower: MI(X;M)=8.336, MI(Y;M)=3.120 | bin: MI(X;M)=12.876, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.694, MI(Y;M)=3.294 | lower: MI(X;M)=7.042, MI(Y;M)=3.072 | bin: MI(X;M)=12.616, MI(Y;M)=3.318
# - Layer 3 upper: MI(X;M)=9.771, MI(Y;M)=3.276 | lower: MI(X;M)=6.632, MI(Y;M)=3.082 | bin: MI(X;M)=11.773, MI(Y;M)=3.312
# - Layer 4 upper: MI(X;M)=3.586, MI(Y;M)=2.901 | lower: MI(X;M)=2.129, MI(Y;M)=1.879 | bin: MI(X;M)=3.432, MI(Y;M)=2.794
# Doing rawdata/tanh_1024-20-20-20/epoch00000080
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.046, MI(Y;M)=3.314 | lower: MI(X;M)=8.365, MI(Y;M)=3.125 | bin: MI(X;M)=12.868, MI(Y;M)=3.318
# - Layer 2 upper: MI(X;M)=10.703, MI(Y;M)=3.295 | lower: MI(X;M)=7.055, MI(Y;M)=3.078 | bin: MI(X;M)=12.613, MI(Y;M)=3.317
# - Layer 3 upper: MI(X;M)=9.773, MI(Y;M)=3.278 | lower: MI(X;M)=6.638, MI(Y;M)=3.089 | bin: MI(X;M)=11.762, MI(Y;M)=3.314
# - Layer 4 upper: MI(X;M)=3.584, MI(Y;M)=2.909 | lower: MI(X;M)=2.146, MI(Y;M)=1.900 | bin: MI(X;M)=3.430, MI(Y;M)=2.798
# Doing rawdata/tanh_1024-20-20-20/epoch00000085
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.063, MI(Y;M)=3.315 | lower: MI(X;M)=8.395, MI(Y;M)=3.130 | bin: MI(X;M)=12.880, MI(Y;M)=3.318
# - Layer 2 upper: MI(X;M)=10.720, MI(Y;M)=3.296 | lower: MI(X;M)=7.068, MI(Y;M)=3.083 | bin: MI(X;M)=12.630, MI(Y;M)=3.318
# - Layer 3 upper: MI(X;M)=9.778, MI(Y;M)=3.280 | lower: MI(X;M)=6.642, MI(Y;M)=3.095 | bin: MI(X;M)=11.743, MI(Y;M)=3.314
# - Layer 4 upper: MI(X;M)=3.582, MI(Y;M)=2.917 | lower: MI(X;M)=2.160, MI(Y;M)=1.917 | bin: MI(X;M)=3.428, MI(Y;M)=2.809
# Doing rawdata/tanh_1024-20-20-20/epoch00000090
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.074, MI(Y;M)=3.315 | lower: MI(X;M)=8.421, MI(Y;M)=3.135 | bin: MI(X;M)=12.874, MI(Y;M)=3.318
# - Layer 2 upper: MI(X;M)=10.733, MI(Y;M)=3.297 | lower: MI(X;M)=7.081, MI(Y;M)=3.088 | bin: MI(X;M)=12.637, MI(Y;M)=3.317
# - Layer 3 upper: MI(X;M)=9.788, MI(Y;M)=3.282 | lower: MI(X;M)=6.651, MI(Y;M)=3.102 | bin: MI(X;M)=11.738, MI(Y;M)=3.314
# - Layer 4 upper: MI(X;M)=3.580, MI(Y;M)=2.925 | lower: MI(X;M)=2.173, MI(Y;M)=1.932 | bin: MI(X;M)=3.426, MI(Y;M)=2.813
# Doing rawdata/tanh_1024-20-20-20/epoch00000095
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.090, MI(Y;M)=3.315 | lower: MI(X;M)=8.457, MI(Y;M)=3.140 | bin: MI(X;M)=12.873, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.750, MI(Y;M)=3.299 | lower: MI(X;M)=7.100, MI(Y;M)=3.093 | bin: MI(X;M)=12.634, MI(Y;M)=3.318
# - Layer 3 upper: MI(X;M)=9.798, MI(Y;M)=3.283 | lower: MI(X;M)=6.661, MI(Y;M)=3.107 | bin: MI(X;M)=11.716, MI(Y;M)=3.315
# - Layer 4 upper: MI(X;M)=3.577, MI(Y;M)=2.931 | lower: MI(X;M)=2.185, MI(Y;M)=1.948 | bin: MI(X;M)=3.425, MI(Y;M)=2.825

# %% [markdown]
# Plot overall summaries
# ----
#
# This is more for diagnostic purposes, not for article

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
sns.set_style('darkgrid')


#PLOT_LAYERS = [0,1,2,3,4] # [1,2,3]
#PLOT_LAYERS = [0,1,2,3]
#PLOT_LAYERS = [0,1,2,3]
plt.figure(figsize=(8,8))
gs = gridspec.GridSpec(4,2)
for actndx, (activation, vals) in enumerate(measures.items()):
    epochs = sorted(vals.keys())
    if not len(epochs):
        continue
        
    plt.subplot(gs[0,actndx])
    for lndx, layerid in enumerate(PLOT_LAYERS):
        xmvalsU = np.array([vals[epoch]['H_M_upper'][layerid] for epoch in epochs])
        if DO_LOWER:
            xmvalsL = np.array([vals[epoch]['H_M_lower'][layerid] for epoch in epochs])
        plt.plot(epochs, xmvalsU, label='Layer %d'%layerid)
        #plt.errorbar(epochs, (xmvalsL + xmvalsU)/2,xmvalsU - xmvalsL, label='Layer %d'%layerid)
    plt.xscale('log')
    plt.yscale('log')
    plt.title(activation)
    plt.ylabel('H(M)')
    
    plt.subplot(gs[1,actndx])
    for lndx, layerid in enumerate(PLOT_LAYERS):
        #for epoch in epochs:
        #    print('her',epoch, measures[activation][epoch]['MI_XM_upper'])
        xmvalsU = np.array([vals[epoch]['MI_XM_upper'][layerid] for epoch in epochs])
        if DO_LOWER:
            xmvalsL = np.array([vals[epoch]['MI_XM_lower'][layerid] for epoch in epochs])
        plt.plot(epochs, xmvalsU, label='Layer %d'%layerid)
        #plt.errorbar(epochs, (xmvalsL + xmvalsU)/2,xmvalsU - xmvalsL, label='Layer %d'%layerid)
    plt.xscale('log')
    plt.ylabel('I(X;M)')


    plt.subplot(gs[2,actndx])
    for lndx, layerid in enumerate(PLOT_LAYERS):
        ymvalsU = np.array([vals[epoch]['MI_YM_upper'][layerid] for epoch in epochs])
        if DO_LOWER:
            ymvalsL = np.array([vals[epoch]['MI_YM_lower'][layerid] for epoch in epochs])
        plt.plot(epochs, ymvalsU, label='Layer %d'%layerid)
    plt.xscale('log')
    plt.ylabel('MI(Y;M)')

    if DO_BINNED:
        plt.subplot(gs[3,actndx])
        for lndx, layerid in enumerate(PLOT_LAYERS):
            hbinnedvals = np.array([vals[epoch]['MI_XM_bin'][layerid] for epoch in epochs])
            plt.semilogx(epochs, hbinnedvals, label='Layer %d'%layerid)
        plt.xlabel('Epoch')
        #plt.ylabel("H'(M)")
        plt.ylabel("I(X;M)bin")
        #plt.yscale('log')
    
    if actndx == 0:
        plt.legend(loc='lower right')
        
plt.tight_layout()

# %% [markdown]
# Plot Infoplane Visualization
# ----

# %%
max_epoch = max( (max(vals.keys()) if len(vals) else 0) for vals in measures.values())
sm = plt.cm.ScalarMappable(cmap='gnuplot', norm=plt.Normalize(vmin=0, vmax=COLORBAR_MAX_EPOCHS))
sm._A = []

fig=plt.figure(figsize=(10,5))
for actndx, (activation, vals) in enumerate(measures.items()):
    epochs = sorted(vals.keys())
    if not len(epochs):
        continue
    plt.subplot(1,2,actndx+1)    
    for epoch in epochs:
        c = sm.to_rgba(epoch)
        xmvals = np.array(vals[epoch]['MI_XM_'+infoplane_measure])[PLOT_LAYERS]
        ymvals = np.array(vals[epoch]['MI_YM_'+infoplane_measure])[PLOT_LAYERS]

        plt.plot(xmvals, ymvals, c=c, alpha=0.1, zorder=1)
        plt.scatter(xmvals, ymvals, s=20, facecolors=[c for _ in PLOT_LAYERS], edgecolor='none', zorder=2)
    
    plt.ylim([0, 3.5])
    plt.xlim([0, 14])
    plt.xlabel('I(X;M)')
    plt.ylabel('I(Y;M)')
    plt.title(activation)
    
cbaxes = fig.add_axes([1.0, 0.125, 0.03, 0.8]) 
plt.colorbar(sm, label='Epoch', cax=cbaxes)
plt.tight_layout()

if DO_SAVE:
    plt.savefig('plots/' + DIR_TEMPLATE % ('infoplane_'+ARCH),bbox_inches='tight')
# Out:
# /home/kamil/Software/anaconda3/envs/tensorflow_gpuenv/lib/python3.7/site-packages/ipykernel_launcher.py:27: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %% [markdown]
# Plot SNR curves
# ----

# %%
plt.figure(figsize=(12,5))

gs = gridspec.GridSpec(len(measures), len(PLOT_LAYERS))
saved_data = {}
for actndx, activation in enumerate(measures.keys()):
    cur_dir = 'rawdata/' + DIR_TEMPLATE % activation
    if not os.path.exists(cur_dir):
        continue
        
    epochs = []
    means = []
    stds = []
    wnorms = []
    trnloss = []
    tstloss = []
    for epochfile in sorted(os.listdir(cur_dir)):
        if not epochfile.startswith('epoch'):
            continue
            
        with open(cur_dir + "/"+epochfile, 'rb') as f:
            d = pickle.load(f)
            
        epoch = d['epoch']
        epochs.append(epoch)
        wnorms.append(d['data']['weights_norm'])
        means.append(d['data']['gradmean'])
        stds.append(d['data']['gradstd'])
        trnloss.append(d['loss']['trn'])
        tstloss.append(d['loss']['tst'])

    wnorms, means, stds, trnloss, tstloss = map(np.array, [wnorms, means, stds, trnloss, tstloss])
    saved_data[activation] = {'wnorms':wnorms, 'means': means, 'stds': stds, 'trnloss': trnloss, 'tstloss':tstloss}

# %%
    
    for lndx,layerid in enumerate(PLOT_LAYERS):
        plt.subplot(gs[actndx, lndx])
        plt.plot(epochs, means[:,layerid], 'b', label="Mean")
        plt.plot(epochs, stds[:,layerid], 'orange', label="Std")
        plt.plot(epochs, means[:,layerid]/stds[:,layerid], 'red', label="SNR")
        plt.plot(epochs, wnorms[:,layerid], 'g', label="||W||")

        plt.title('%s - Layer %d'%(activation, layerid))
        plt.xlabel('Epoch')
        plt.gca().set_xscale("log", nonposx='clip')
        plt.gca().set_yscale("log", nonposy='clip')
    

plt.legend(loc='lower left', bbox_to_anchor=(1.1, 0.2))
plt.tight_layout()

if DO_SAVE:
    plt.savefig('plots/' + DIR_TEMPLATE % ('snr_'+ARCH), bbox_inches='tight')

# %%
GRID_PLOT_LAYERS = [0,1,2,3] # [1,2,3]
sns.set_style('whitegrid')
max_epoch = max( (max(vals.keys()) if len(vals) else 0) for vals in measures.values())
H_X = np.log2(10000)
for actndx, (activation, vals) in enumerate(measures.items()):
    fig = plt.figure(figsize=(12,11))
    gs = gridspec.GridSpec(4, len(GRID_PLOT_LAYERS))
    epochs = np.array(sorted(vals.keys()))
    if not len(epochs):
        continue
        
    plt.subplot(gs[0,0])
    plt.title('Loss')
    plt.xlabel('Epoch')
    plt.plot(epochs,saved_data[activation]['trnloss']/np.log(2), label='Train')
    plt.plot(epochs,saved_data[activation]['tstloss']/np.log(2), label='Test')
    plt.ylabel('Cross entropy loss')
    plt.gca().set_xscale("log", nonposx='clip')
    
    plt.legend(loc='upper right', frameon=True)
        
    vals_binned = np.array([vals[epoch]['MI_XM_bin'] for epoch in epochs])
    vals_lower = np.array([vals[epoch]['MI_XM_lower'] for epoch in epochs])
    vals_upper = np.array([vals[epoch]['MI_XM_upper'] for epoch in epochs])
    for layerndx, layerid in enumerate(GRID_PLOT_LAYERS):
        plt.subplot(gs[1,layerndx])
        plt.plot(epochs, epochs*0 + H_X, 'k:', label=r'$H(X)$')
        plt.fill_between(epochs, vals_lower[:,layerid], vals_upper[:,layerid])
        plt.gca().set_xscale("log", nonposx='clip')
        plt.ylim([0, 1.1*H_X])
        plt.title('Layer %d Mutual Info (KDE)'%(layerid+1))
        plt.ylabel(r'$I(X;T)$')
        plt.xlabel('Epoch')
        if layerndx == len(GRID_PLOT_LAYERS)-1:
            plt.legend(loc='lower right', frameon=True)
        
        plt.subplot(gs[2,layerndx])
        plt.plot(epochs, epochs*0 + H_X, 'k:', label=r'$H(X)$')
        plt.plot(epochs, vals_binned[:,layerid])
        plt.gca().set_xscale("log", nonposx='clip')
        plt.ylim([0, 1.1*H_X])
        plt.ylabel(r'$I(X;T)$')
        plt.title('Layer %d Mutual Info (binned)'%(layerid+1))
        plt.xlabel('Epoch')
        if layerndx == len(GRID_PLOT_LAYERS)-1:
            plt.legend(loc='lower right', frameon=True)
        
        plt.subplot(gs[3,layerndx])
        plt.title('Layer %d SNR'%(layerid+1))
        plt.plot(epochs, saved_data[activation]['means'][:,layerid], 'b', label="Mean")
        plt.plot(epochs, saved_data[activation]['stds'][:,layerid], 'orange', label="Std")
        plt.plot(epochs, saved_data[activation]['means'][:,layerid]/saved_data[activation]['stds'][:,layerid], 'red', label="SNR")
        plt.plot(epochs, saved_data[activation]['wnorms'][:,layerid], 'g', label="||W||")

        plt.xlabel('Epoch')
        plt.gca().set_xscale("log", nonposx='clip')
        plt.gca().set_yscale("log", nonposy='clip')
    
    plt.tight_layout()
    plt.legend(loc='lower left', frameon=True)
    
    if DO_SAVE:
        plt.savefig('plots/' + DIR_TEMPLATE % ('gridplot_'+activation) + '.pdf', bbox_inches='tight')
