# %%
import keras
import keras.backend as K
import numpy as np

import utils
import loggingreporter 

cfg = {}
cfg['SGD_BATCHSIZE']    = 128
cfg['SGD_LEARNINGRATE'] = 0.001
cfg['NUM_EPOCHS']       = 100 #10000

cfg['ACTIVATION'] = 'relu'
#cfg['ACTIVATION'] = 'tanh'
# How many hidden neurons to put into each of the layers
cfg['LAYER_DIMS'] = [1024, 20, 20, 20]
#cfg['LAYER_DIMS'] = [32, 28, 24, 20, 16, 12, 8, 8]
#cfg['LAYER_DIMS'] = [128, 64, 32, 16, 16] # 0.967 w. 128
#cfg['LAYER_DIMS'] = [20, 20, 20, 20, 20, 20] # 0.967 w. 128
ARCH_NAME =  '-'.join(map(str,cfg['LAYER_DIMS']))
trn, tst = utils.get_mnist()

# Where to save activation and weights data
cfg['SAVE_DIR'] = 'rawdata/' + cfg['ACTIVATION'] + '_' + ARCH_NAME
# Out:
# Using TensorFlow backend.

# %%
input_layer  = keras.layers.Input((trn.X.shape[1],))
clayer = input_layer
for n in cfg['LAYER_DIMS']:
    clayer = keras.layers.Dense(n, activation=cfg['ACTIVATION'])(clayer)
output_layer = keras.layers.Dense(trn.nb_classes, activation='softmax')(clayer)

model = keras.models.Model(inputs=input_layer, outputs=output_layer)
optimizer = keras.optimizers.SGD(lr=cfg['SGD_LEARNINGRATE'])

model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From /home/kamil/Software/anaconda3/envs/tensorflow_gpuenv/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
def do_report(epoch):
    # Only log activity for some epochs.  Mainly this is to make things run faster.
    if epoch < 20:       # Log for all first 20 epochs
        return True
    elif epoch < 100:    # Then for every 5th epoch
        return (epoch % 5 == 0)
    elif epoch < 200:    # Then every 10th
        return (epoch % 10 == 0)
    else:                # Then every 100th
        return (epoch % 100 == 0)
    
reporter = loggingreporter.LoggingReporter(cfg=cfg, 
                                          trn=trn, 
                                          tst=tst, 
                                          do_save_func=do_report)
r = model.fit(x=trn.X, y=trn.Y, 
              verbose    = 2, 
              batch_size = cfg['SGD_BATCHSIZE'],
              epochs     = cfg['NUM_EPOCHS'],
              # validation_data=(tst.X, tst.Y),
              callbacks  = [reporter,])
# Out:
# WARNING:tensorflow:From /home/kamil/Software/anaconda3/envs/tensorflow_gpuenv/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Making directory rawdata/relu_1024-20-20-20
# Epoch 1/100
# /home/kamil/Software/anaconda3/envs/tensorflow_gpuenv/lib/python3.7/site-packages/keras/callbacks.py:99: UserWarning: Method on_batch_begin() is slow compared to the batch update (0.584746). Check your callbacks.
#   % delta_t_median)
#  - 5s - loss: 2.2588 - acc: 0.1529
# Saving rawdata/relu_1024-20-20-20/epoch00000000
# Epoch 2/100
#  - 3s - loss: 2.1415 - acc: 0.2039
# Saving rawdata/relu_1024-20-20-20/epoch00000001
# Epoch 3/100
#  - 3s - loss: 1.9984 - acc: 0.2466
# Saving rawdata/relu_1024-20-20-20/epoch00000002
# Epoch 4/100
#  - 3s - loss: 1.8441 - acc: 0.3243
# Saving rawdata/relu_1024-20-20-20/epoch00000003
# Epoch 5/100
#  - 3s - loss: 1.6738 - acc: 0.4669
# Saving rawdata/relu_1024-20-20-20/epoch00000004
# Epoch 6/100
#  - 3s - loss: 1.4840 - acc: 0.5864
# Saving rawdata/relu_1024-20-20-20/epoch00000005
# Epoch 7/100
#  - 3s - loss: 1.2833 - acc: 0.6552
# Saving rawdata/relu_1024-20-20-20/epoch00000006
# Epoch 8/100
#  - 3s - loss: 1.0983 - acc: 0.7067
# Saving rawdata/relu_1024-20-20-20/epoch00000007
# Epoch 9/100
#  - 3s - loss: 0.9508 - acc: 0.7541
# Saving rawdata/relu_1024-20-20-20/epoch00000008
# Epoch 10/100
#  - 3s - loss: 0.8369 - acc: 0.7858
# Saving rawdata/relu_1024-20-20-20/epoch00000009
# Epoch 11/100
#  - 3s - loss: 0.7468 - acc: 0.8077
# Saving rawdata/relu_1024-20-20-20/epoch00000010
# Epoch 12/100
#  - 3s - loss: 0.6741 - acc: 0.8252
# Saving rawdata/relu_1024-20-20-20/epoch00000011
# Epoch 13/100
#  - 3s - loss: 0.6149 - acc: 0.8391
# Saving rawdata/relu_1024-20-20-20/epoch00000012
# Epoch 14/100
#  - 3s - loss: 0.5663 - acc: 0.8511
# Saving rawdata/relu_1024-20-20-20/epoch00000013
# Epoch 15/100
#  - 3s - loss: 0.5265 - acc: 0.8595
# Saving rawdata/relu_1024-20-20-20/epoch00000014
# Epoch 16/100
#  - 3s - loss: 0.4938 - acc: 0.8671
# Saving rawdata/relu_1024-20-20-20/epoch00000015
# Epoch 17/100
#  - 3s - loss: 0.4671 - acc: 0.8734
# Saving rawdata/relu_1024-20-20-20/epoch00000016
# Epoch 18/100
#  - 3s - loss: 0.4453 - acc: 0.8782
# Saving rawdata/relu_1024-20-20-20/epoch00000017
# Epoch 19/100
#  - 3s - loss: 0.4272 - acc: 0.8824
# Saving rawdata/relu_1024-20-20-20/epoch00000018
# Epoch 20/100
#  - 3s - loss: 0.4117 - acc: 0.8863
# Saving rawdata/relu_1024-20-20-20/epoch00000019
# Epoch 21/100
#  - 3s - loss: 0.3980 - acc: 0.8900
# Saving rawdata/relu_1024-20-20-20/epoch00000020
# Epoch 22/100
#  - 1s - loss: 0.3860 - acc: 0.8931
# Epoch 23/100
#  - 1s - loss: 0.3752 - acc: 0.8956
# Epoch 24/100
#  - 1s - loss: 0.3653 - acc: 0.8982
# Epoch 25/100
#  - 1s - loss: 0.3562 - acc: 0.9008
# Epoch 26/100
#  - 3s - loss: 0.3478 - acc: 0.9034
# Saving rawdata/relu_1024-20-20-20/epoch00000025
# Epoch 27/100
#  - 1s - loss: 0.3400 - acc: 0.9051
# Epoch 28/100
#  - 1s - loss: 0.3327 - acc: 0.9068
# Epoch 29/100
#  - 1s - loss: 0.3258 - acc: 0.9088
# Epoch 30/100
#  - 1s - loss: 0.3192 - acc: 0.9104
# Epoch 31/100
#  - 2s - loss: 0.3130 - acc: 0.9125
# Saving rawdata/relu_1024-20-20-20/epoch00000030
# Epoch 32/100
#  - 1s - loss: 0.3070 - acc: 0.9143
# Epoch 33/100
#  - 1s - loss: 0.3013 - acc: 0.9159
# Epoch 34/100
#  - 1s - loss: 0.2958 - acc: 0.9172
# Epoch 35/100
#  - 1s - loss: 0.2907 - acc: 0.9181
# Epoch 36/100
#  - 3s - loss: 0.2855 - acc: 0.9200
# Saving rawdata/relu_1024-20-20-20/epoch00000035
# Epoch 37/100
#  - 1s - loss: 0.2806 - acc: 0.9212
# Epoch 38/100
#  - 1s - loss: 0.2760 - acc: 0.9227
# Epoch 39/100
#  - 1s - loss: 0.2714 - acc: 0.9237
# Epoch 40/100
#  - 1s - loss: 0.2670 - acc: 0.9245
# Epoch 41/100
#  - 2s - loss: 0.2626 - acc: 0.9260
# Saving rawdata/relu_1024-20-20-20/epoch00000040
# Epoch 42/100
#  - 1s - loss: 0.2584 - acc: 0.9270
# Epoch 43/100
#  - 1s - loss: 0.2545 - acc: 0.9285
# Epoch 44/100
#  - 1s - loss: 0.2505 - acc: 0.9295
# Epoch 45/100
#  - 1s - loss: 0.2467 - acc: 0.9309
# Epoch 46/100
#  - 2s - loss: 0.2430 - acc: 0.9316
# Saving rawdata/relu_1024-20-20-20/epoch00000045
# Epoch 47/100
#  - 1s - loss: 0.2393 - acc: 0.9327
# Epoch 48/100
#  - 1s - loss: 0.2358 - acc: 0.9335
# Epoch 49/100
#  - 1s - loss: 0.2324 - acc: 0.9344
# Epoch 50/100
#  - 1s - loss: 0.2289 - acc: 0.9353
# Epoch 51/100
#  - 2s - loss: 0.2257 - acc: 0.9365
# Saving rawdata/relu_1024-20-20-20/epoch00000050
# Epoch 52/100
#  - 1s - loss: 0.2226 - acc: 0.9374
# Epoch 53/100
#  - 1s - loss: 0.2193 - acc: 0.9386
# Epoch 54/100
#  - 1s - loss: 0.2163 - acc: 0.9391
# Epoch 55/100
#  - 1s - loss: 0.2133 - acc: 0.9403
# Epoch 56/100
#  - 2s - loss: 0.2102 - acc: 0.9410
# Saving rawdata/relu_1024-20-20-20/epoch00000055
# Epoch 57/100
#  - 1s - loss: 0.2075 - acc: 0.9413
# Epoch 58/100
#  - 1s - loss: 0.2047 - acc: 0.9420
# Epoch 59/100
#  - 1s - loss: 0.2021 - acc: 0.9429
# Epoch 60/100
#  - 1s - loss: 0.1994 - acc: 0.9437
# Epoch 61/100
#  - 3s - loss: 0.1968 - acc: 0.9445
# Saving rawdata/relu_1024-20-20-20/epoch00000060
# Epoch 62/100
#  - 1s - loss: 0.1942 - acc: 0.9451
# Epoch 63/100
#  - 1s - loss: 0.1917 - acc: 0.9458
# Epoch 64/100
#  - 1s - loss: 0.1893 - acc: 0.9466
# Epoch 65/100
#  - 1s - loss: 0.1869 - acc: 0.9472
# Epoch 66/100
#  - 3s - loss: 0.1845 - acc: 0.9477
# Saving rawdata/relu_1024-20-20-20/epoch00000065
# Epoch 67/100
#  - 1s - loss: 0.1823 - acc: 0.9487
# Epoch 68/100
#  - 1s - loss: 0.1800 - acc: 0.9489
# Epoch 69/100
#  - 1s - loss: 0.1778 - acc: 0.9498
# Epoch 70/100
#  - 1s - loss: 0.1757 - acc: 0.9501
# Epoch 71/100
#  - 2s - loss: 0.1736 - acc: 0.9507
# Saving rawdata/relu_1024-20-20-20/epoch00000070
# Epoch 72/100
#  - 1s - loss: 0.1714 - acc: 0.9513
# Epoch 73/100
#  - 1s - loss: 0.1696 - acc: 0.9520
# Epoch 74/100
#  - 1s - loss: 0.1676 - acc: 0.9524
# Epoch 75/100
#  - 1s - loss: 0.1657 - acc: 0.9530
# Epoch 76/100
#  - 3s - loss: 0.1638 - acc: 0.9538
# Saving rawdata/relu_1024-20-20-20/epoch00000075
# Epoch 77/100
#  - 1s - loss: 0.1619 - acc: 0.9540
# Epoch 78/100
#  - 1s - loss: 0.1602 - acc: 0.9546
# Epoch 79/100
#  - 1s - loss: 0.1584 - acc: 0.9550
# Epoch 80/100
#  - 1s - loss: 0.1567 - acc: 0.9556
# Epoch 81/100
#  - 2s - loss: 0.1549 - acc: 0.9559
# Saving rawdata/relu_1024-20-20-20/epoch00000080
# Epoch 82/100
#  - 1s - loss: 0.1534 - acc: 0.9565
# Epoch 83/100
#  - 1s - loss: 0.1518 - acc: 0.9569
# Epoch 84/100
#  - 1s - loss: 0.1501 - acc: 0.9571
# Epoch 85/100
#  - 1s - loss: 0.1486 - acc: 0.9577
# Epoch 86/100
#  - 2s - loss: 0.1471 - acc: 0.9583
# Saving rawdata/relu_1024-20-20-20/epoch00000085
# Epoch 87/100
#  - 1s - loss: 0.1456 - acc: 0.9587
# Epoch 88/100
#  - 1s - loss: 0.1441 - acc: 0.9588
# Epoch 89/100
#  - 1s - loss: 0.1426 - acc: 0.9594
# Epoch 90/100
#  - 1s - loss: 0.1413 - acc: 0.9597
# Epoch 91/100
#  - 2s - loss: 0.1399 - acc: 0.9604
# Saving rawdata/relu_1024-20-20-20/epoch00000090
# Epoch 92/100
#  - 1s - loss: 0.1384 - acc: 0.9609
# Epoch 93/100
#  - 1s - loss: 0.1372 - acc: 0.9613
# Epoch 94/100
#  - 1s - loss: 0.1359 - acc: 0.9613
# Epoch 95/100
#  - 1s - loss: 0.1346 - acc: 0.9616
# Epoch 96/100
#  - 2s - loss: 0.1333 - acc: 0.9622
# Saving rawdata/relu_1024-20-20-20/epoch00000095
# Epoch 97/100
#  - 1s - loss: 0.1321 - acc: 0.9625
# Epoch 98/100
#  - 1s - loss: 0.1309 - acc: 0.9631
# Epoch 99/100
#  - 1s - loss: 0.1296 - acc: 0.9637
# Epoch 100/100
#  - 1s - loss: 0.1285 - acc: 0.9637
